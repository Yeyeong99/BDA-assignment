# %%
# 리스트를 만들기

df = ['기초','기본','응용1','응용2']

# %%
#2차원 리스트

df_2 = [['기초','기본','응용1','응용2']]

# %%
df_2[0][0]
# Out:
# '기초'

# %%
df_2[0][2]
# Out:
# '응용1'

# %%
df_2[1][0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-20-6d4d4bad6a82> in <cell line: 1>()
# ----> 1 df_2[1][0]
#
# IndexError: list index out of range

# %%
df_2[3][0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-d59b2e5af9a4> in <cell line: 1>()
# ----> 1 df_2[3][0]
#
# IndexError: list index out of range

# %% [markdown]
# ### 데이터프레임 구조로 만들기!

# %%
import pandas as pd

# %%
df_bda=pd.DataFrame({
    '구분': ['기초','기본','응용1','응용2'],
    '총 인원':[1000,2000,3000,4000],
    '우수학회원수':[200,400,600,800]
})

# %%
df_bda
# Out:
#     구분  총 인원  우수학회원수
# 0   기초  1000     200
# 1   기본  2000     400
# 2  응용1  3000     600
# 3  응용2  4000     800

# %%
df_bda[0][0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-e60076d053eb> in <cell line: 1>()
# ----> 1 df_bda[0][0]
#
# ...

# %%
df_bda.iloc[0][2]
# Out:
# <ipython-input-26-9885e09b35d9>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df_bda.iloc[0][2]
# 200

# %%
## 패키지를 이용해서 데이터를 불러오자!
import seaborn as sns

tt=sns.load_dataset('titanic')

# %%
tt.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
#데이터셋을 불러와서 가지고 오자!

mpg=pd.read_csv('mpg.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-29-925cb8dd382f> in <cell line: 3>()
#       1 #데이터셋을 불러와서 가지고 오자!
#       2
# ----> 3 mpg=pd.read_csv('mpg.csv')
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
mpg
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-957257d6878d> in <cell line: 1>()
# ----> 1 mpg
#
# NameError: name 'mpg' is not defined

# %% [markdown]
# ### 데이터프레임에 대한 구조를 제대로 이해하자!
#
# - 데이터프레임은 2차원 구조 -> 행/열
#     - 예를 불러오려면 행과 열 기준으로 불러오면 된다.
#     - 열기준으로 불러오기
#     - [['']] 대괄호 안에 대괄호를 넣어서 불러오면 된다.
#
#         - [['컬럼1','컬럼2'.,,,,'컬럼N']]

# %%
df_bda
# Out:
#     구분  총 인원  우수학회원수
# 0   기초  1000     200
# 1   기본  2000     400
# 2  응용1  3000     600
# 3  응용2  4000     800

# %%
df_bda[['구분','우수학회원수']]
# Out:
#     구분  우수학회원수
# 0   기초     200
# 1   기본     400
# 2  응용1     600
# 3  응용2     800

# %%
tt
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tt[['age','embarked','class']]
# Out:
#       age embarked   class
# 0    22.0        S   Third
# 1    38.0        C   First
# 2    26.0        S   Third
# 3    35.0        S   First
# 4    35.0        S   Third
# ..    ...      ...     ...
# 886  27.0        S  Second
# 887  19.0        S   First
# 888   NaN        S   Third
# 889  26.0        C   First
# 890  32.0        Q   Third
#
# [891 rows x 3 columns]

# %%
df_bda[['구분']]
# Out:
#     구분
# 0   기초
# 1   기본
# 2  응용1
# 3  응용2

# %%
df_bda['구분']
# Out:
# 0     기초
# 1     기본
# 2    응용1
# 3    응용2
# Name: 구분, dtype: object

# %%
## 시리즈형태는 1차원
## 1차원을 불러오려면 컬럼 하나만 사용하면 된다.

type(df_bda[['구분']])
# Out:
# pandas.core.frame.DataFrame

# %%
#대괄호 1개로 감싸면
type(df_bda['구분'])
# Out:
# pandas.core.series.Series

# %%
tt['fare']*1000
# Out:
# 0       7250.0
# 1      71283.3
# 2       7925.0
# 3      53100.0
# 4       8050.0
#         ...
# 886    13000.0
# 887    30000.0
# 888    23450.0
# 889    30000.0
# 890     7750.0
# Name: fare, Length: 891, dtype: float64

# %%
df
# Out:
# ['기초', '기본', '응용1', '응용2']

# %%
## 반복문 리스트 접근시?
for i in df:
    print(i)
# Out:
# 기초
# 기본
# 응용1
# 응용2

# %%
## 데이터프레임은 반복문을 어떻게 접근하지?

# %%
df_bda
# Out:
#     구분  총 인원  우수학회원수
# 0   기초  1000     200
# 1   기본  2000     400
# 2  응용1  3000     600
# 3  응용2  4000     800

# %%
for i in df_bda:
    print(i)
# Out:
# 구분
# 총 인원
# 우수학회원수

# %%
for i in df_bda['총 인원']:
    print(i)
# Out:
# 1000
# 2000
# 3000
# 4000

# %%
df_bda[['우수학회원수','구분']]
# Out:
#    우수학회원수   구분
# 0     200   기초
# 1     400   기본
# 2     600  응용1
# 3     800  응용2

# %%
for i in df_bda[['우수학회원수','총 인원']]:
    print(i)
# Out:
# 우수학회원수
# 총 인원

# %%
list(df_bda['구분'])
# Out:
# ['기초', '기본', '응용1', '응용2']

# %%
tt
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
for i in list(tt['fare']):
    print(i*10000)
# Out:
# 72500.0
# 712833.0
# 79250.0
# 531000.0
# 80500.0
# 84583.0
# 518625.0
# 210750.0
# 111333.0
# 300708.0
# 167000.0
# 265500.0
# 80500.0
# 312750.0
# 78542.0
# 160000.0
# 291250.0
# 130000.0
# 180000.0
# 72250.0
# 260000.0
# 130000.0
# 80292.0
# 355000.0
# 210750.0
# 313875.0
# 72250.0
# 2630000.0
# 78792.0
# 78958.0
# 277208.0
# 1465208.0
# 77500.0
# 105000.0
# 821708.0
# 520000.0
# 72292.0
# 80500.0
# 180000.0
# 112417.0
# 94750.0
# 210000.0
# 78958.0
# 415792.0
# 78792.0
# 80500.0
# 155000.0
# 77500.0
# 216792.00000000003
# 178000.0
# 396875.0
# 78000.0
# 767292.0000000001
# 260000.0
# 619792.0
# 355000.0
# 105000.0
# 72292.0
# 277500.0
# 469000.0
# 72292.0
# 800000.0
# 834750.0
# 279000.0
# 277208.0
# 152458.0
# 105000.0
# 81583.0
# 79250.0
# 86625.0
# 105000.0
# 469000.0
# 735000.0
# 144542.0
# 564958.0
# 76500.0
# 78958.0
# 80500.0
# 290000.0
# 124750.0
# 90000.0
# 95000.0
# 77875.0
# 471000.0
# 105000.0
# 158500.0
# 343750.0
# 80500.0
# 2630000.0
# 80500.0
# 80500.0
# 78542.0
# ...

# %% [markdown]
# ### 통계반 자료

# %%
#판다스에서 제공하는 데이터 타입들 한 눈에 확인할 수 있다.
tt['fare'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 891 entries, 0 to 890
# Series name: fare
# Non-Null Count  Dtype
# --------------  -----
# 891 non-null    float64
# dtypes: float64(1)
# memory usage: 7.1 KB

# %%
tt
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
#기초통계요약
tt['fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: fare, dtype: float64

# %%
tt.describe(include='all')
# Out:
#           survived      pclass   sex         age       sibsp       parch  \
# count   891.000000  891.000000   891  714.000000  891.000000  891.000000
# unique         NaN         NaN     2         NaN         NaN         NaN
# top            NaN         NaN  male         NaN         NaN         NaN
# freq           NaN         NaN   577         NaN         NaN         NaN
# mean      0.383838    2.308642   NaN   29.699118    0.523008    0.381594
# std       0.486592    0.836071   NaN   14.526497    1.102743    0.806057
# min       0.000000    1.000000   NaN    0.420000    0.000000    0.000000
# 25%       0.000000    2.000000   NaN   20.125000    0.000000    0.000000
# 50%       0.000000    3.000000   NaN   28.000000    0.000000    0.000000
# 75%       1.000000    3.000000   NaN   38.000000    1.000000    0.000000
# max       1.000000    3.000000   NaN   80.000000    8.000000    6.000000
#
#               fare embarked  class  who adult_male deck  embark_town alive  \
# ...
