# %%
# 주어진 데이터 셋에서 age컬럼 상위 20개의 데이터를 구한 다음 
# f1의 결측치를 중앙값으로 채운다.
# 그리고 f4가 ISFJ와 f5가 20 이상인 
# f1의 평균값을 출력하시오!

# - 데이터셋 : basic1.csv 
# - 오른쪽 상단 copy&edit 클릭 -> 예상문제 풀이 시작
# - File -> Editor Type -> Script

import pandas as pd

# 데이터 불러오기
df = pd.read_csv("../input/bigdatacertificationkr/basic1.csv")

# %%
df.reset_index().sort_values('age', ascending=False).head(20)
# Out:
#     index    id    age city    f1  f2   f3    f4         f5
# 96     96  id97  100.0   경기   NaN   0  NaN  INFP  67.886373
# 36     36  id37  100.0   부산   NaN   0  NaN  ESTP  33.308999
# 44     44  id45   97.0   대구  88.0   0  NaN  ENFJ  13.049921
# 51     51  id52   97.0   대구  82.0   1  NaN  ISFJ  90.496999
# 91     91  id92   97.0   경기  78.0   1  NaN  INFP  97.381034
# 9       9  id10   95.0   서울  74.0   1  NaN  ISFP  98.429899
# 45     45  id46   93.0   대구   NaN   0  NaN  ESTJ  67.886373
# 77     77  id78   92.0   경기  96.0   1  NaN  INTJ  69.730313
# 95     95  id96   92.0   경기  53.0   1  NaN  ENTJ  52.667078
# 72     72  id73   90.0   경기   NaN   1  NaN  ISFJ  73.586397
# 20     20  id21   90.0   부산   NaN   1  NaN  ISFP  29.269869
# 87     87  id88   89.0   경기  75.0   0  NaN  ESTJ  60.339826
# 62     62  id63   88.0   경기  86.0   1  NaN  ISFJ  73.586397
# 65     65  id66   87.0   경기   NaN   1  NaN  ISFP  17.252986
# 37     37  id38   87.0   부산   NaN   1  NaN  ESTP  83.685380
# 60     60  id61   87.0   경기  62.0   2  NaN  INTP  69.730313
# 49     49  id50   86.0   대구  78.0   1  NaN  ENFP  60.339826
# 80     80  id81   86.0   경기  50.0   1  NaN  ISFJ  37.113739
# 30     30  id31   86.0   부산  77.0   0  NaN  ESFJ  73.586397
# 93     93  id94   84.0   경기   NaN   1  NaN  ESTJ  90.496999

# %%
df['f1'] = df['f1'].fillna(df['f1'].median())

# %%
df.head(4)
# Out:
#      id   age city    f1  f2   f3    f4         f5
# 0  id01   2.0   서울  63.0   0  NaN  ENFJ  91.297791
# 1  id02   9.0   서울  70.0   1  NaN  ENFJ  60.339826
# 2  id03  27.0   서울  61.0   1  NaN  ISTJ  17.252986
# 3  id04  75.0   서울  63.0   2  NaN  INFP  52.667078

# %%
# 그리고 f4가 ISFJ와 f5가 20 이상인 
# f1의 평균값을 출력하시오!

df[(df.f4 == 'ISFJ') & (df.f5 >= 20)].f1.mean()
# Out:
# 77.0

# %%
# 나이 순(내림차순)으로 정렬
df = df.sort_values('age', ascending=False).reset_index(drop=True)
print(df)

# 상위 20개 슬라이싱
df = df[:20]
print(df)

# 결측치 채우기 (중앙값)
df['f1'] = df['f1'].fillna(df['f1'].median())

# 조건 ISFJ, f5가 20이상
cond = (df['f4']=='ISFJ') & (df['f5'] >= 20)

# f1의 평균
print(df[cond]['f1'].mean())

# 정답 : 73.875
# Out:
#       id    age city     f1  f2   f3    f4         f5
# 0   id97  100.0   경기   63.0   0  NaN  INFP  67.886373
# 1   id37  100.0   부산   63.0   0  NaN  ESTP  33.308999
# 2   id45   97.0   대구   88.0   0  NaN  ENFJ  13.049921
# 3   id52   97.0   대구   82.0   1  NaN  ISFJ  90.496999
# 4   id92   97.0   경기   78.0   1  NaN  INFP  97.381034
# ..   ...    ...  ...    ...  ..  ...   ...        ...
# 95  id99    1.0   경기   47.0   0  NaN  ESFJ  97.381034
# 96  id58    0.0   대구  100.0   2  NaN  ESTP  33.308999
# 97  id22   -6.3   부산   72.0   1  NaN  ENFP  52.667078
# 98  id70   -9.0   경기   96.0   1  NaN  ISTP  48.431184
# 99  id29  -13.5   부산   47.0   2  NaN  ENTP  67.886373
#
# [100 rows x 8 columns]
#       id    age city    f1  f2   f3    f4         f5
# 0   id97  100.0   경기  63.0   0  NaN  INFP  67.886373
# 1   id37  100.0   부산  63.0   0  NaN  ESTP  33.308999
# 2   id45   97.0   대구  88.0   0  NaN  ENFJ  13.049921
# 3   id52   97.0   대구  82.0   1  NaN  ISFJ  90.496999
# 4   id92   97.0   경기  78.0   1  NaN  INFP  97.381034
# 5   id10   95.0   서울  74.0   1  NaN  ISFP  98.429899
# 6   id46   93.0   대구  63.0   0  NaN  ESTJ  67.886373
# 7   id78   92.0   경기  96.0   1  NaN  INTJ  69.730313
# 8   id96   92.0   경기  53.0   1  NaN  ENTJ  52.667078
# 9   id73   90.0   경기  63.0   1  NaN  ISFJ  73.586397
# 10  id21   90.0   부산  63.0   1  NaN  ISFP  29.269869
# 11  id88   89.0   경기  75.0   0  NaN  ESTJ  60.339826
# 12  id63   88.0   경기  86.0   1  NaN  ISFJ  73.586397
# 13  id66   87.0   경기  63.0   1  NaN  ISFP  17.252986
# 14  id38   87.0   부산  63.0   1  NaN  ESTP  83.685380
# 15  id61   87.0   경기  62.0   2  NaN  INTP  69.730313
# 16  id50   86.0   대구  78.0   1  NaN  ENFP  60.339826
# 17  id81   86.0   경기  50.0   1  NaN  ISFJ  37.113739
# 18  id31   86.0   부산  77.0   0  NaN  ESFJ  73.586397
# 19  id94   84.0   경기  63.0   1  NaN  ESTJ  90.496999
# 70.25
